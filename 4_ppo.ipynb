# %% [markdown]
# #### Importance Sampling
# - $p(x)$ is a P.D.F.
# $$\mathbb{E}_{x \sim p}[f(x)] \approx \frac{1}{N}\sum_{i=1}^Nf(x^i)$$
#
# Problem: We do not know the distribution $p(x)$
#
# We can sample it from $q(x)$, a P.D.F.
#
# $$
# \begin{align*}
# \mathbb{E}_{x \sim p}[f(x)] &= \int f(x)p(x)dx \\
#                             &= \int f(x)\frac{p(x)}{q(x)}q(x)dx \\
#                             &= \mathbb{E}_{x \sim q}[f(x)\frac{p(x)}{q(x)}]
# \end{align*}
# $$
#
# #### Question:
#
# Note:
# $\text{Var}[X] = \mathbb{E}[X^2] - (\mathbb{E}(x))^2$
#
# $$\mathbb{E}_{x \sim p}[f(x)] = \mathbb{E}_{x \sim q}[f(x)\frac{p(x)}{q(x)}]$$
# $$\text{Var}_{x \sim p}[f(x)] \text{ ? } \text{Var}_{x \sim q}[f(x)\frac{p(x)}{q(x)}]$$
#
#
# **See:**
#
# $$\text{Var}_{x\sim p}[f(x)] = \mathbb{E}_{x \sim p}[f(x)^2] - (\mathbb{E}_{x \sim p}[f(x)])^2$$
#
# $$
# \begin{align*}
# \text{Var}_{x \sim q}[f(x)\frac{p(x)}{q(x)}] &= \mathbb{E}_{x \sim q}\left[\left(f(x)\frac{p(x)}{q(x)}\right)^2\right] - \left(\mathbb{E}_{x \sim q} \left[f(x)\frac{p(x)}{q(x)}\right]\right)^2 \\
# &= \mathbb{E}_{x\sim p}\left[f(x)^2\frac{p(x)}{q(x)}\right] - (\mathbb{E}_{x\sim p}[f(x)])^2
# \end{align*}
# $$

# %% [markdown]
# 这个过程的关键在于利用了变量替换和期望的定义。我们知道，对于随机变量 $X$，其期望 $\mathbb{E}[X]$ 的定义是 $\int x p(x) dx$，其中 $p(x)$ 是 $X$ 的概率分布函数。因此，我们可以将期望从 $q$ 分布转换到 $p$ 分布。
#
# 对于第一个期望 $\mathbb{E}_{x \sim q}\left[\left(f(x)\frac{p(x)}{q(x)}\right)^2\right]$，我们可以写成
#
# $$
# \mathbb{E}{x \sim q}\left[\left(f(x)\frac{p(x)}{q(x)}\right)^2\right] = \int \left(f(x)\frac{p(x)}{q(x)}\right)^2 q(x) dx = \int f(x)^2\frac{p(x)}{q(x)} p(x) dx = \mathbb{E}{x\sim p}\left[f(x)^2\frac{p(x)}{q(x)}\right]
# $$
#
# 对于第二个期望 $\mathbb{E}_{x \sim q} \left[f(x)\frac{p(x)}{q(x)}\right]$，我们可以写成
#
# $$
# \mathbb{E}{x \sim q} \left[f(x)\frac{p(x)}{q(x)}\right] = \int f(x)\frac{p(x)}{q(x)} q(x) dx = \int f(x) p(x) dx = \mathbb{E}{x\sim p}[f(x)]
# $$
#
# 因此，我们得到了
#
# $$
# \text{Var}{x \sim q}[f(x)\frac{p(x)}{q(x)}] = \mathbb{E}{x\sim p}\left[f(x)^2\frac{p(x)}{q(x)}\right] - (\mathbb{E}_{x\sim p}[f(x)])^2
# $$
# 这就是推导的过程。

# %% [markdown]
# 比较发现, 第一项不同. $p(x)$和$q(x)$的差距不能很大.

# %% [markdown]
# ----
#
# #### On-policy to Off-policy
#
# $$\nabla \bar{R}_\theta = \mathbb{E}_{\tau \sim p_\theta(\tau)}[R(\tau)\nabla \log p_\theta(\tau)]$$
# - Use $\pi_\theta$ to collect data, when $\theta$ is updated, we have to sample training data agian.
# - Goal: Using the sample from $\pi_{\theta^\prime}$ to train $\theta$. $\theta^\prime$ is fixed, so we can re-use the sample data.
#
# $$
# \begin{align*}
# \nabla \bar{R}_\theta = \mathbb{E}_{\tau \sim p_{\theta^\prime}(\tau)}\left[\frac{p_\theta(\tau)}{p_{\theta^\prime}(\tau)}R(\tau)\nabla \log p_\theta(\tau)\right]
# \end{align*}
# $$
#
# $\theta^\prime$是负责和环境做互动, 示范给$\theta$
# - Sample the data from $\theta^\prime$.
# - Use the data to train $\theta$ many times.

# %% [markdown]
# #### Gradient for Update
# Using agent $\theta$ to sample state and action pair.
#
# > $A^\theta(s_t, a_t)$ 估算出来, 在现在的state, 采取动作$a_t$是好的还是不好的.
#
# $$
# \begin{align*}
# &= \mathbb{E}_{(s_t, a_t) \sim \pi_\theta}\left[A^\theta(s_t, a_t)\nabla \log p_\theta(a_t^n\mid s_t^n)\right] \\
# & \text{Using important sampling} \\
# &= \mathbb{E}_{(s_t, a_t)\sim \pi_{\theta^\prime}}\left[\frac{p_\theta(s_t, a_t)}{p_{\theta^\prime}(s_t, a_t)} A^{\theta^\prime}(s_t, a_t)\nabla \log p_\theta(a_t^n\mid s_t^n)\right] \\
# & \text{Some math}\\
# &=\mathbb{E}_{(s_t, a_t) \sim \pi_{\theta^\prime}}\left[\frac{p_\theta(a_t\mid s_t)}{p_{\theta^\prime}(a_t\mid s_t)}A^{\theta^\prime}(s_t, a_t) \nabla \log p_\theta(a_t^n\mid s_t^n)\right]
# \end{align*}
# $$
#
# Thus, the objective function:
#
# $$
# \begin{align*}
# \mathcal{J}^{\theta^\prime}(\theta) = \mathbb{E}_{(s_t, a_t) \sim \pi_{\theta^\prime}}\left[\frac{p_\theta(a_t\mid s_t)}{p_{\theta^\prime}(a_t \mid s_t)}A^{\theta^\prime}(s_t, a_t)\right]
# \end{align*}
# $$

# %% [markdown]
# #### 如何避免$p(x)$和$q(x)$相差太多?
#
# ##### PPO (adding the constrains)

# %% [markdown]
# $$\mathcal{J}^{\theta^\prime}(\theta) = \mathcal{J}^{\theta^\prime}(\theta) - \beta\text{KL}(\theta, \theta^\prime)$$

# %% [markdown]
# Process of PPO
# - Initial policy parameters $\theta^0$.
# - In each iteration $k$
#     - Using $\theta^k$ to interact with the environment to collect $\{s_t, a_t\}$ and compute advantage $A^{\theta^k}(s_t, a_t)$
#     - Find $\theta$ optimizing $\mathcal{J}_{\text{PPO}}^{\theta^k}(\theta) = \mathcal{J}^{\theta^k}(\theta) - \beta \text{KL}(\theta, \theta^k)$

# %% [markdown]
# ---
# - $\theta^\prime$是真正与环境交互的.
# - $\theta$是更新的, agent的参数.
# ---

# %%
import torch
import torch.nn as nn
from torch.distributions import Categorical 
import gym

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class Memory:
    def __init__(self):
        self.actions = []
        self.states = []
        self.logprobs = []
        self.rewards = []
        self.is_terminals = []
    
    def clear_memory(self):
        del self.actions[:]
        del self.states[:]
        del self.logprobs[:]
        del self.rewards[:]
        del self.is_terminals[:]

# %%
class ActorCritic(nn.Module):
    def __init__(self, state_dim, action_dim, n_latent_var):
        super(ActorCritic, self).__init__()
        
        # actor
        self.action_layer = nn.Sequential(
            nn.Linear(state_dim, n_latent_var),
            nn.Tanh(),
            nn.Linear(n_latent_var, n_latent_var),
            nn.Linear(n_latent_var, action_dim),
            nn.Softmax(dim=-1)
        )
        
        # critic
        self.value_layer = nn.Sequential(
            nn.Linear(state_dim, n_latent_var),
            nn.Tanh(),
            nn.Linear(n_latent_var, n_latent_var),
            nn.Linear(n_latent_var, 1)
        )
        
    def forward(self):
        raise NotImplementedError
    
    def act(self, state, memory):
        state = torch.from_numpy(state).float().to(device)
        action_probs = self.action_layer(state)
        dist = Categorical(action_probs)
        action = dist.sample()
        
        memory.states.append(state)
        memory.actions.append(action)
        memory.logprobs.append(dist.log_prob(action))
        
        state_value = self.value_layer(state)
        
        return action.item()
    
    def evaluate(self, state, action):
        action_probs = self.action_layer(state)
        dist = Categorical(action_probs)
        
        action_logprobs = dist.log_prob(action)
        dist_entropy = dist.entropy()
        
        state_value = self.value_layer(state)
        
        return action_logprobs, torch.squeeze(state_value), dist_entropy

# %%
class PPO:
    def __init__(self, state_dim, action_dim, n_latent_var, lr, betas, gamma, K_epochs, eps_clip):
        self.lr = lr 
        self.betas = betas
        self.gamma = gamma
        self.eps_clip = eps_clip
        self.K_epochs = K_epochs
        
        self.policy = ActorCritic(state_dim, action_dim, n_latent_var).to(device)
        self.optimizer = torch.optim.Adam(self.policy.parameters(), lr=lr, betas=betas)
        self.policy_old = ActorCritic(state_dim, action_dim, n_latent_var).to(device)
        self.policy_old.load_state_dict(self.policy.state_dict())
        
        self.MseLoss = nn.MSELoss()
        
    def update(self, memory):
        
        # Monte Carlo estimate of state rewards
        rewards = []
        discounted_reward = 0
        for reward, is_terminal in zip(reversed(memory.rewards), reversed(memory.is_terminals)):
            if is_terminal:
                discounted_reward = 0
            discounted_reward = reward + (self.gamma * discounted_reward)
            rewards.insert(0, discounted_reward)
            
        # Normalizing the rewards
        rewards = torch.tensor(rewards, dtype=torch.float32).to(device)
        rewards = (rewards - rewards.mean())/(rewards.std() + 1e-5)
        
        # convert list to tensor
        old_states = torch.stack(memory.states).to(device).detach()
        old_actions = torch.stack(memory.actions).to(device).detach()
        old_logprobs = torch.stack(memory.logprobs).to(device).detach()
        
        # Optimize policy for K epochs:
        for _ in range(self.K_epochs):
            # Evalating old actions and values:
            logprobs, state_values, dist_entropy = self.policy.evaluate(old_states, old_actions)
            # Finding the ratio (pi_theta / pi_theta_old)
            ratios = torch.exp(logprobs - old_logprobs.detach())
            
            # Finding Surrogate loss:
            advantages = rewards - state_values.detach()
            surr1 = ratios * advantages
            surr2 = torch.clamp(ratios, 1-self.eps_clip, 1+self.eps_clip)*advantages
            loss = -torch.min(surr1, surr2) + 0.5*self.MseLoss(state_values, rewards) - 0.01*dist_entropy
            
            # take gradient step
            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()
            
        self.policy_old.load_state_dict(self.policy.state_dict())

# %%
render = True

# %%
env_name = "LunarLander-v2"
env = gym.make(env_name)
state_dim = env.observation_space.shape[0]

# %%
state_dim
# Out:
# 8

# %%
action_dim = 4
solved_reward = 230 # stop training if avg_reward > solved_reward
log_interval = 20 # pring avg reard in the interval
max_episodes = 50000 # max training episodes
max_timesteps = 300 # max timesteps in one episodes
n_latent_var = 64 
update_timestep = 2000 # update policy every n timesteps
lr = 0.002
betas = (0.9, 0.999)
gamma = 0.99
K_epochs = 4
eps_clip = 0.2
random_seed = None

# %%
memory = Memory()
ppo = PPO(state_dim, action_dim, n_latent_var, lr, betas, gamma, K_epochs, eps_clip)

# Logging vars
running_reward = 0
avg_length = 0
timestep = 0

for i_episode in range(1, max_episodes+1):
    state, _ = env.reset()
    for t in range(max_timesteps):
        timestep += 1
        
        # Running policy old:
        action = ppo.policy_old.act(state, memory)
        state, reward, done, _, _ = env.step(action)
        
        # saving reward and is_terminal
        memory.rewards.append(reward)
        memory.is_terminals.append(done)
        
        # update if its time 
        if timestep % update_timestep == 0:
            ppo.update(memory)
            memory.clear_memory()
            timestep = 0
        
        running_reward += reward
        if render:
            env.render()
        if done:
            break
        
    avg_length += t
    
    # stop training if avg_reward > solved_reward
    if running_reward > (log_interval*solved_reward):
        print('#### Solved! ######')
        torch.save(ppo.policy.state_dict(), './PPO_{}.pth'.format(env_name))
        break
    
    if i_episode % log_interval == 0:
        avg_length = int(avg_length/log_interval)
        running_reward = int((running_reward/log_interval))
        
        print('Episode {} \t avg length: {} \t reward: {}'.format(i_episode, avg_length, running_reward))
        running_reward = 0
        avg_length = 0
# Out:
# Episode 20 	 avg length: 92 	 reward: -211
# Episode 40 	 avg length: 99 	 reward: -128
# Episode 60 	 avg length: 90 	 reward: -148
# Episode 80 	 avg length: 94 	 reward: -154
# Episode 100 	 avg length: 99 	 reward: -119
# Episode 120 	 avg length: 102 	 reward: -158
# Episode 140 	 avg length: 130 	 reward: -152
# Episode 160 	 avg length: 151 	 reward: -247
# Episode 180 	 avg length: 156 	 reward: -199
# Episode 200 	 avg length: 132 	 reward: -109
# Episode 220 	 avg length: 138 	 reward: -117
# Episode 240 	 avg length: 164 	 reward: -98
# Episode 260 	 avg length: 228 	 reward: -101
# Episode 280 	 avg length: 211 	 reward: -25
# Episode 300 	 avg length: 167 	 reward: -5
# Episode 320 	 avg length: 266 	 reward: 15
# Episode 340 	 avg length: 269 	 reward: 40
# Episode 360 	 avg length: 246 	 reward: 54
# Episode 380 	 avg length: 254 	 reward: 43
# Episode 400 	 avg length: 266 	 reward: 79
# Episode 420 	 avg length: 235 	 reward: 77
# Episode 440 	 avg length: 203 	 reward: 52
# Episode 460 	 avg length: 231 	 reward: 72
# Episode 480 	 avg length: 171 	 reward: 46
# Episode 500 	 avg length: 197 	 reward: 65
# Episode 520 	 avg length: 239 	 reward: 71
# Episode 540 	 avg length: 236 	 reward: 66
# Episode 560 	 avg length: 276 	 reward: 100
# Episode 580 	 avg length: 222 	 reward: 74
# Episode 600 	 avg length: 259 	 reward: 106
# Episode 620 	 avg length: 282 	 reward: 125
# Episode 640 	 avg length: 261 	 reward: 106
# Episode 660 	 avg length: 284 	 reward: 127
# Episode 680 	 avg length: 238 	 reward: 87
# Episode 700 	 avg length: 265 	 reward: 106
# Episode 720 	 avg length: 234 	 reward: 90
# Episode 740 	 avg length: 218 	 reward: 92
# Episode 760 	 avg length: 233 	 reward: 83
# Episode 780 	 avg length: 191 	 reward: 66
# Episode 800 	 avg length: 226 	 reward: 94
# Episode 820 	 avg length: 215 	 reward: 80
# Episode 840 	 avg length: 252 	 reward: 95
# Episode 860 	 avg length: 281 	 reward: 105
# Episode 880 	 avg length: 289 	 reward: 118
# Episode 900 	 avg length: 299 	 reward: 123
# Episode 920 	 avg length: 283 	 reward: 110
# Episode 940 	 avg length: 255 	 reward: 112
# Episode 960 	 avg length: 255 	 reward: 113
# Episode 980 	 avg length: 254 	 reward: 122
# Episode 1000 	 avg length: 262 	 reward: 124
# Episode 1020 	 avg length: 266 	 reward: 115
# Episode 1040 	 avg length: 247 	 reward: 81
# Episode 1060 	 avg length: 254 	 reward: 101
# Episode 1080 	 avg length: 259 	 reward: 108
# Episode 1100 	 avg length: 233 	 reward: 100
# Episode 1120 	 avg length: 273 	 reward: 111
# Episode 1140 	 avg length: 272 	 reward: 124
# Episode 1160 	 avg length: 255 	 reward: 115
# Episode 1180 	 avg length: 247 	 reward: 112
# Episode 1200 	 avg length: 248 	 reward: 119
# Episode 1220 	 avg length: 269 	 reward: 135
# Episode 1240 	 avg length: 290 	 reward: 145
# Episode 1260 	 avg length: 292 	 reward: 145
# Episode 1280 	 avg length: 283 	 reward: 122
# Episode 1300 	 avg length: 244 	 reward: 105
# Episode 1320 	 avg length: 266 	 reward: 130
# Episode 1340 	 avg length: 284 	 reward: 149
# Episode 1360 	 avg length: 280 	 reward: 161
# Episode 1380 	 avg length: 274 	 reward: 146
# Episode 1400 	 avg length: 292 	 reward: 167
# Episode 1420 	 avg length: 269 	 reward: 147
# Episode 1440 	 avg length: 237 	 reward: 113
# Episode 1460 	 avg length: 288 	 reward: 138
# Episode 1480 	 avg length: 285 	 reward: 146
# Episode 1500 	 avg length: 282 	 reward: 157
# Episode 1520 	 avg length: 287 	 reward: 139
# Episode 1540 	 avg length: 282 	 reward: 155
# Episode 1560 	 avg length: 283 	 reward: 141
# Episode 1580 	 avg length: 289 	 reward: 145
# Episode 1600 	 avg length: 277 	 reward: 144
# Episode 1620 	 avg length: 279 	 reward: 147
# Episode 1640 	 avg length: 241 	 reward: 106
# Episode 1660 	 avg length: 278 	 reward: 142
# Episode 1680 	 avg length: 269 	 reward: 141
# Episode 1700 	 avg length: 291 	 reward: 162
# Episode 1720 	 avg length: 269 	 reward: 125
# Episode 1740 	 avg length: 259 	 reward: 134
# Episode 1760 	 avg length: 286 	 reward: 138
# Episode 1780 	 avg length: 285 	 reward: 150
# Episode 1800 	 avg length: 292 	 reward: 152
# Episode 1820 	 avg length: 283 	 reward: 138
# Episode 1840 	 avg length: 299 	 reward: 168
# Episode 1860 	 avg length: 281 	 reward: 146
# Episode 1880 	 avg length: 256 	 reward: 117
# Episode 1900 	 avg length: 294 	 reward: 159
# Episode 1920 	 avg length: 285 	 reward: 151
# Episode 1940 	 avg length: 291 	 reward: 163
# Episode 1960 	 avg length: 292 	 reward: 160
# Episode 1980 	 avg length: 288 	 reward: 154
# Episode 2000 	 avg length: 273 	 reward: 148
# Episode 2020 	 avg length: 256 	 reward: 137
# Episode 2040 	 avg length: 283 	 reward: 143
# Episode 2060 	 avg length: 258 	 reward: 131
# Episode 2080 	 avg length: 258 	 reward: 129
# Episode 2100 	 avg length: 293 	 reward: 162
# Episode 2120 	 avg length: 285 	 reward: 147
# Episode 2140 	 avg length: 299 	 reward: 158
# Episode 2160 	 avg length: 278 	 reward: 138
# Episode 2180 	 avg length: 269 	 reward: 129
# Episode 2200 	 avg length: 275 	 reward: 149
# Episode 2220 	 avg length: 272 	 reward: 151
# Episode 2240 	 avg length: 278 	 reward: 150
# Episode 2260 	 avg length: 257 	 reward: 137
# Episode 2280 	 avg length: 299 	 reward: 172
# Episode 2300 	 avg length: 292 	 reward: 160
# Episode 2320 	 avg length: 286 	 reward: 147
# Episode 2340 	 avg length: 275 	 reward: 137
# Episode 2360 	 avg length: 273 	 reward: 139
# Episode 2380 	 avg length: 273 	 reward: 152
# Episode 2400 	 avg length: 289 	 reward: 166
# Episode 2420 	 avg length: 270 	 reward: 142
# Episode 2440 	 avg length: 270 	 reward: 138
# Episode 2460 	 avg length: 282 	 reward: 160
# Episode 2480 	 avg length: 270 	 reward: 142
# Episode 2500 	 avg length: 265 	 reward: 138
# Episode 2520 	 avg length: 280 	 reward: 154
# Episode 2540 	 avg length: 292 	 reward: 152
# Episode 2560 	 avg length: 277 	 reward: 144
# Episode 2580 	 avg length: 297 	 reward: 168
# Episode 2600 	 avg length: 293 	 reward: 141
# Episode 2620 	 avg length: 290 	 reward: 154
# Episode 2640 	 avg length: 246 	 reward: 114
# Episode 2660 	 avg length: 292 	 reward: 160
# Episode 2680 	 avg length: 292 	 reward: 149
# Episode 2700 	 avg length: 299 	 reward: 149
# Episode 2720 	 avg length: 299 	 reward: 164
# Episode 2740 	 avg length: 270 	 reward: 139
# Episode 2760 	 avg length: 277 	 reward: 146
# Episode 2780 	 avg length: 274 	 reward: 160
# Episode 2800 	 avg length: 278 	 reward: 142
# Episode 2820 	 avg length: 272 	 reward: 135
# Episode 2840 	 avg length: 258 	 reward: 115
# Episode 2860 	 avg length: 286 	 reward: 140
# Episode 2880 	 avg length: 280 	 reward: 133
# Episode 2900 	 avg length: 277 	 reward: 145
# Episode 2920 	 avg length: 286 	 reward: 165
# Episode 2940 	 avg length: 274 	 reward: 149
# Episode 2960 	 avg length: 258 	 reward: 148
# Episode 2980 	 avg length: 280 	 reward: 151
# Episode 3000 	 avg length: 254 	 reward: 122
# Episode 3020 	 avg length: 275 	 reward: 139
# Episode 3040 	 avg length: 274 	 reward: 135
# Episode 3060 	 avg length: 283 	 reward: 156
# Episode 3080 	 avg length: 299 	 reward: 175
# Episode 3100 	 avg length: 271 	 reward: 154
# Episode 3120 	 avg length: 241 	 reward: 123
# Episode 3140 	 avg length: 262 	 reward: 134
# Episode 3160 	 avg length: 224 	 reward: 113
# Episode 3180 	 avg length: 246 	 reward: 124
# Episode 3200 	 avg length: 269 	 reward: 121
# Episode 3220 	 avg length: 266 	 reward: 140
# Episode 3240 	 avg length: 285 	 reward: 146
# Episode 3260 	 avg length: 264 	 reward: 153
# Episode 3280 	 avg length: 274 	 reward: 149
# Episode 3300 	 avg length: 269 	 reward: 148
# Episode 3320 	 avg length: 270 	 reward: 146
# Episode 3340 	 avg length: 242 	 reward: 122
# Episode 3360 	 avg length: 242 	 reward: 129
# Episode 3380 	 avg length: 281 	 reward: 155
# Episode 3400 	 avg length: 265 	 reward: 136
# Episode 3420 	 avg length: 209 	 reward: 99
# Episode 3440 	 avg length: 224 	 reward: 107
# Episode 3460 	 avg length: 211 	 reward: 93
# Episode 3480 	 avg length: 225 	 reward: 100
# Episode 3500 	 avg length: 174 	 reward: 62
# Episode 3520 	 avg length: 251 	 reward: 47
# Episode 3540 	 avg length: 275 	 reward: 153
# Episode 3560 	 avg length: 268 	 reward: 118
# Episode 3580 	 avg length: 206 	 reward: 76
# Episode 3600 	 avg length: 256 	 reward: 119
# Episode 3620 	 avg length: 262 	 reward: 138
# Episode 3640 	 avg length: 199 	 reward: 65
# Episode 3660 	 avg length: 251 	 reward: 121
# Episode 3680 	 avg length: 222 	 reward: 83
# Episode 3700 	 avg length: 265 	 reward: 150
# Episode 3720 	 avg length: 269 	 reward: 141
# Episode 3740 	 avg length: 237 	 reward: 102
# Episode 3760 	 avg length: 212 	 reward: 91
# Episode 3780 	 avg length: 190 	 reward: 81
# Episode 3800 	 avg length: 253 	 reward: 129
# Episode 3820 	 avg length: 255 	 reward: 128
# Episode 3840 	 avg length: 248 	 reward: 125
# Episode 3860 	 avg length: 200 	 reward: 64
# Episode 3880 	 avg length: 275 	 reward: 153
# Episode 3900 	 avg length: 262 	 reward: 133
# Episode 3920 	 avg length: 292 	 reward: 166
# Episode 3940 	 avg length: 260 	 reward: 135
# Episode 3960 	 avg length: 285 	 reward: 147
# Episode 3980 	 avg length: 265 	 reward: 136
# Episode 4000 	 avg length: 252 	 reward: 126
# Episode 4020 	 avg length: 265 	 reward: 144
# Episode 4040 	 avg length: 285 	 reward: 161
# Episode 4060 	 avg length: 276 	 reward: 149
# Episode 4080 	 avg length: 264 	 reward: 132
# Episode 4100 	 avg length: 292 	 reward: 178
# Episode 4120 	 avg length: 292 	 reward: 163
# Episode 4140 	 avg length: 283 	 reward: 146
# Episode 4160 	 avg length: 258 	 reward: 123
# Episode 4180 	 avg length: 299 	 reward: 166
# Episode 4200 	 avg length: 299 	 reward: 157
# Episode 4220 	 avg length: 289 	 reward: 161
# Episode 4240 	 avg length: 252 	 reward: 135
# Episode 4260 	 avg length: 231 	 reward: 97
# Episode 4280 	 avg length: 281 	 reward: 155
# Episode 4300 	 avg length: 234 	 reward: 121
# Episode 4320 	 avg length: 248 	 reward: 116
# Episode 4340 	 avg length: 235 	 reward: 112
# Episode 4360 	 avg length: 299 	 reward: 168
# Episode 4380 	 avg length: 261 	 reward: 143
# Episode 4400 	 avg length: 262 	 reward: 143
# Episode 4420 	 avg length: 291 	 reward: 163
# Episode 4440 	 avg length: 282 	 reward: 147
# Episode 4460 	 avg length: 283 	 reward: 152
# Episode 4480 	 avg length: 246 	 reward: 125
# Episode 4500 	 avg length: 257 	 reward: 135
# Episode 4520 	 avg length: 268 	 reward: 147
# Episode 4540 	 avg length: 273 	 reward: 150
# Episode 4560 	 avg length: 263 	 reward: 138
# Episode 4580 	 avg length: 283 	 reward: 149
# Episode 4600 	 avg length: 282 	 reward: 147
# Episode 4620 	 avg length: 272 	 reward: 154
# Episode 4640 	 avg length: 297 	 reward: 169
# Episode 4660 	 avg length: 288 	 reward: 147
# Episode 4680 	 avg length: 267 	 reward: 143
# Episode 4700 	 avg length: 287 	 reward: 162
# Episode 4720 	 avg length: 265 	 reward: 140
# Episode 4740 	 avg length: 223 	 reward: 112
# Episode 4760 	 avg length: 242 	 reward: 121
# Episode 4780 	 avg length: 266 	 reward: 141
# Episode 4800 	 avg length: 269 	 reward: 146
# Episode 4820 	 avg length: 264 	 reward: 141
# Episode 4840 	 avg length: 262 	 reward: 131
# Episode 4860 	 avg length: 271 	 reward: 144
# Episode 4880 	 avg length: 289 	 reward: 160
# Episode 4900 	 avg length: 258 	 reward: 146
# Episode 4920 	 avg length: 250 	 reward: 135
# Episode 4940 	 avg length: 299 	 reward: 153
# Episode 4960 	 avg length: 235 	 reward: 103
# Episode 4980 	 avg length: 246 	 reward: 104
# Episode 5000 	 avg length: 228 	 reward: 78
# Episode 5020 	 avg length: 274 	 reward: 132
# Episode 5040 	 avg length: 284 	 reward: 131
# Episode 5060 	 avg length: 244 	 reward: 110
# Episode 5080 	 avg length: 250 	 reward: 128
# Episode 5100 	 avg length: 273 	 reward: 135
# Episode 5120 	 avg length: 268 	 reward: 106
# Episode 5140 	 avg length: 251 	 reward: 116
# Episode 5160 	 avg length: 225 	 reward: 124
# Episode 5180 	 avg length: 225 	 reward: 99
# Episode 5200 	 avg length: 223 	 reward: 112
# Episode 5220 	 avg length: 244 	 reward: 95
# Episode 5240 	 avg length: 195 	 reward: 80
# Episode 5260 	 avg length: 259 	 reward: 131
# Episode 5280 	 avg length: 210 	 reward: 92
# Episode 5300 	 avg length: 202 	 reward: 105
# Episode 5320 	 avg length: 261 	 reward: 154
# Episode 5340 	 avg length: 259 	 reward: 142
# Episode 5360 	 avg length: 197 	 reward: 79
# Episode 5380 	 avg length: 221 	 reward: 95
# Episode 5400 	 avg length: 227 	 reward: 102
# Episode 5420 	 avg length: 254 	 reward: 140
# Episode 5440 	 avg length: 221 	 reward: 80
# Episode 5460 	 avg length: 212 	 reward: 137
# Episode 5480 	 avg length: 249 	 reward: 133
# Episode 5500 	 avg length: 237 	 reward: 128
# Episode 5520 	 avg length: 205 	 reward: 92
# Episode 5540 	 avg length: 202 	 reward: 82
# Episode 5560 	 avg length: 240 	 reward: 143
# Episode 5580 	 avg length: 241 	 reward: 129
# Episode 5600 	 avg length: 249 	 reward: 111
# Episode 5620 	 avg length: 235 	 reward: 138
# Episode 5640 	 avg length: 259 	 reward: 132
# Episode 5660 	 avg length: 269 	 reward: 133
# Episode 5680 	 avg length: 264 	 reward: 120
# Episode 5700 	 avg length: 231 	 reward: 119
# Episode 5720 	 avg length: 223 	 reward: 134
# Episode 5740 	 avg length: 179 	 reward: 54
# Episode 5760 	 avg length: 164 	 reward: 71
# Episode 5780 	 avg length: 205 	 reward: 91
# Episode 5800 	 avg length: 235 	 reward: 127
# Episode 5820 	 avg length: 204 	 reward: 102
# Episode 5840 	 avg length: 215 	 reward: 98
# Episode 5860 	 avg length: 187 	 reward: 71
# Episode 5880 	 avg length: 197 	 reward: 99
# Episode 5900 	 avg length: 267 	 reward: 156
# Episode 5920 	 avg length: 231 	 reward: 103
# Episode 5940 	 avg length: 200 	 reward: 94
# Episode 5960 	 avg length: 231 	 reward: 106
# Episode 5980 	 avg length: 221 	 reward: 83
# Episode 6000 	 avg length: 209 	 reward: 82
# Episode 6020 	 avg length: 220 	 reward: 100
# Episode 6040 	 avg length: 271 	 reward: 135
# Episode 6060 	 avg length: 234 	 reward: 127
# Episode 6080 	 avg length: 266 	 reward: 106
# Episode 6100 	 avg length: 217 	 reward: 89
# Episode 6120 	 avg length: 229 	 reward: 76
# Episode 6140 	 avg length: 251 	 reward: 126
# Episode 6160 	 avg length: 266 	 reward: 138
# Episode 6180 	 avg length: 246 	 reward: 94
# Episode 6200 	 avg length: 232 	 reward: 107
# Episode 6220 	 avg length: 211 	 reward: 98
# Episode 6240 	 avg length: 176 	 reward: 46
# Episode 6260 	 avg length: 229 	 reward: 113
# Episode 6280 	 avg length: 219 	 reward: 81
# Episode 6300 	 avg length: 188 	 reward: 75
# Episode 6320 	 avg length: 230 	 reward: 96
# Episode 6340 	 avg length: 252 	 reward: 141
# Episode 6360 	 avg length: 198 	 reward: 96
# Episode 6380 	 avg length: 217 	 reward: 99
# Episode 6400 	 avg length: 224 	 reward: 78
# Episode 6420 	 avg length: 231 	 reward: 107
# Episode 6440 	 avg length: 214 	 reward: 99
# Episode 6460 	 avg length: 178 	 reward: 55
# Episode 6480 	 avg length: 206 	 reward: 74
# Episode 6500 	 avg length: 218 	 reward: 80
# Episode 6520 	 avg length: 231 	 reward: 93
# Episode 6540 	 avg length: 283 	 reward: 141
# Episode 6560 	 avg length: 254 	 reward: 85
# Episode 6580 	 avg length: 258 	 reward: 106
# Episode 6600 	 avg length: 213 	 reward: 82
# Episode 6620 	 avg length: 224 	 reward: 53
# Episode 6640 	 avg length: 242 	 reward: 102
# Episode 6660 	 avg length: 222 	 reward: 96
# Episode 6680 	 avg length: 225 	 reward: 76
# Episode 6700 	 avg length: 236 	 reward: 84
# Episode 6720 	 avg length: 221 	 reward: 101
# Episode 6740 	 avg length: 246 	 reward: 99
# Episode 6760 	 avg length: 232 	 reward: 44
# Episode 6780 	 avg length: 220 	 reward: 68
# Episode 6800 	 avg length: 179 	 reward: 65
# Episode 6820 	 avg length: 230 	 reward: 109
# Episode 6840 	 avg length: 207 	 reward: 57
# Episode 6860 	 avg length: 259 	 reward: 113
# Episode 6880 	 avg length: 256 	 reward: 117
# Episode 6900 	 avg length: 229 	 reward: 97
# Episode 6920 	 avg length: 218 	 reward: 58
# Episode 6940 	 avg length: 166 	 reward: 70
# Episode 6960 	 avg length: 203 	 reward: 27
# Episode 6980 	 avg length: 172 	 reward: -16
# Episode 7000 	 avg length: 174 	 reward: -8
# Episode 7020 	 avg length: 212 	 reward: 19
# Episode 7040 	 avg length: 235 	 reward: 40
# Episode 7060 	 avg length: 244 	 reward: 94
# Episode 7080 	 avg length: 228 	 reward: 55
# Episode 7100 	 avg length: 206 	 reward: 25
# Episode 7120 	 avg length: 239 	 reward: -20
# Episode 7140 	 avg length: 193 	 reward: 42
# Episode 7160 	 avg length: 202 	 reward: 41
# Episode 7180 	 avg length: 181 	 reward: 4
# Episode 7200 	 avg length: 216 	 reward: 37
# Episode 7220 	 avg length: 196 	 reward: 85
# Episode 7240 	 avg length: 225 	 reward: 75
# Episode 7260 	 avg length: 265 	 reward: 121
# Episode 7280 	 avg length: 201 	 reward: 77
# Episode 7300 	 avg length: 217 	 reward: 52
# Episode 7320 	 avg length: 202 	 reward: 83
# Episode 7340 	 avg length: 213 	 reward: 94
# Episode 7360 	 avg length: 223 	 reward: 101
# Episode 7380 	 avg length: 275 	 reward: 139
# Episode 7400 	 avg length: 197 	 reward: 92
# Episode 7420 	 avg length: 236 	 reward: 115
# Episode 7440 	 avg length: 228 	 reward: 106
# Episode 7460 	 avg length: 257 	 reward: 126
# Episode 7480 	 avg length: 267 	 reward: 120
# Episode 7500 	 avg length: 242 	 reward: 111
# Episode 7520 	 avg length: 246 	 reward: 130
# Episode 7540 	 avg length: 216 	 reward: 109
# Episode 7560 	 avg length: 225 	 reward: 121
# Episode 7580 	 avg length: 223 	 reward: 116
# Episode 7600 	 avg length: 209 	 reward: 103
# Episode 7620 	 avg length: 209 	 reward: 110
# Episode 7640 	 avg length: 236 	 reward: 111
# Episode 7660 	 avg length: 227 	 reward: 109
# Episode 7680 	 avg length: 231 	 reward: 147
# Episode 7700 	 avg length: 251 	 reward: 121
# Episode 7720 	 avg length: 235 	 reward: 125
# Episode 7740 	 avg length: 169 	 reward: 73
# Episode 7760 	 avg length: 217 	 reward: 106
# Episode 7780 	 avg length: 232 	 reward: 120
# Episode 7800 	 avg length: 232 	 reward: 124
# Episode 7820 	 avg length: 222 	 reward: 130
# Episode 7840 	 avg length: 219 	 reward: 105
# Episode 7860 	 avg length: 229 	 reward: 113
# Episode 7880 	 avg length: 233 	 reward: 110
# Episode 7900 	 avg length: 253 	 reward: 140
# Episode 7920 	 avg length: 212 	 reward: 115
# Episode 7940 	 avg length: 253 	 reward: 136
# Episode 7960 	 avg length: 225 	 reward: 115
# Episode 7980 	 avg length: 276 	 reward: 134
# Episode 8000 	 avg length: 245 	 reward: 112
# Episode 8020 	 avg length: 217 	 reward: 112
# Episode 8040 	 avg length: 257 	 reward: 126
# Episode 8060 	 avg length: 250 	 reward: 120
# Episode 8080 	 avg length: 249 	 reward: 138
# Episode 8100 	 avg length: 240 	 reward: 99
# Episode 8120 	 avg length: 220 	 reward: 118
# Episode 8140 	 avg length: 249 	 reward: 142
# Episode 8160 	 avg length: 241 	 reward: 91
# Episode 8180 	 avg length: 239 	 reward: 124
# Episode 8200 	 avg length: 214 	 reward: 64
# Episode 8220 	 avg length: 228 	 reward: 97
# Episode 8240 	 avg length: 212 	 reward: 87
# Episode 8260 	 avg length: 222 	 reward: 104
# Episode 8280 	 avg length: 223 	 reward: 88
# Episode 8300 	 avg length: 226 	 reward: 104
# Episode 8320 	 avg length: 247 	 reward: 154
# Episode 8340 	 avg length: 229 	 reward: 125
# Episode 8360 	 avg length: 260 	 reward: 125
# Episode 8380 	 avg length: 245 	 reward: 110
# Episode 8400 	 avg length: 199 	 reward: 86
# Episode 8420 	 avg length: 256 	 reward: 146
# Episode 8440 	 avg length: 210 	 reward: 116
# Episode 8460 	 avg length: 271 	 reward: 148
# Episode 8480 	 avg length: 229 	 reward: 136
# Episode 8500 	 avg length: 233 	 reward: 120
# Episode 8520 	 avg length: 174 	 reward: 66
# Episode 8540 	 avg length: 216 	 reward: 116
# Episode 8560 	 avg length: 225 	 reward: 107
# Episode 8580 	 avg length: 221 	 reward: 100
# Episode 8600 	 avg length: 229 	 reward: 118
# Episode 8620 	 avg length: 201 	 reward: 101
# Episode 8640 	 avg length: 217 	 reward: 103
# Episode 8660 	 avg length: 218 	 reward: 123
# Episode 8680 	 avg length: 207 	 reward: 92
# Episode 8700 	 avg length: 246 	 reward: 135
# Episode 8720 	 avg length: 213 	 reward: 128
# Episode 8740 	 avg length: 241 	 reward: 134
# Episode 8760 	 avg length: 188 	 reward: 100
# Episode 8780 	 avg length: 195 	 reward: 109
# Episode 8800 	 avg length: 225 	 reward: 115
# Episode 8820 	 avg length: 231 	 reward: 131
# Episode 8840 	 avg length: 218 	 reward: 130
# Episode 8860 	 avg length: 229 	 reward: 113
# Episode 8880 	 avg length: 229 	 reward: 131
# Episode 8900 	 avg length: 190 	 reward: 95
# Episode 8920 	 avg length: 213 	 reward: 97
# Episode 8940 	 avg length: 234 	 reward: 127
# Episode 8960 	 avg length: 250 	 reward: 132
# Episode 8980 	 avg length: 251 	 reward: 128
# Episode 9000 	 avg length: 255 	 reward: 137
# Episode 9020 	 avg length: 213 	 reward: 121
# Episode 9040 	 avg length: 246 	 reward: 112
# Episode 9060 	 avg length: 227 	 reward: 131
# Episode 9080 	 avg length: 213 	 reward: 104
# Episode 9100 	 avg length: 237 	 reward: 130
# Episode 9120 	 avg length: 228 	 reward: 125
# Episode 9140 	 avg length: 194 	 reward: 96
# Episode 9160 	 avg length: 191 	 reward: 90
# Episode 9180 	 avg length: 211 	 reward: 129
# Episode 9200 	 avg length: 224 	 reward: 124
# Episode 9220 	 avg length: 236 	 reward: 145
# Episode 9240 	 avg length: 202 	 reward: 114
# Episode 9260 	 avg length: 199 	 reward: 127
# Episode 9280 	 avg length: 241 	 reward: 122
# Episode 9300 	 avg length: 202 	 reward: 96
# Episode 9320 	 avg length: 243 	 reward: 133
# Episode 9340 	 avg length: 217 	 reward: 118
# Episode 9360 	 avg length: 218 	 reward: 109
# Episode 9380 	 avg length: 231 	 reward: 135
# Episode 9400 	 avg length: 242 	 reward: 135
# Episode 9420 	 avg length: 216 	 reward: 112
# Episode 9440 	 avg length: 193 	 reward: 122
# Episode 9460 	 avg length: 211 	 reward: 102
# Episode 9480 	 avg length: 248 	 reward: 171
# Episode 9500 	 avg length: 217 	 reward: 114
# Episode 9520 	 avg length: 197 	 reward: 97
# Episode 9540 	 avg length: 214 	 reward: 98
# Episode 9560 	 avg length: 235 	 reward: 128
# Episode 9580 	 avg length: 207 	 reward: 118
# Episode 9600 	 avg length: 174 	 reward: 76
# Episode 9620 	 avg length: 188 	 reward: 87
# Episode 9640 	 avg length: 173 	 reward: 92
# Episode 9660 	 avg length: 183 	 reward: 84
# Episode 9680 	 avg length: 206 	 reward: 111
# Episode 9700 	 avg length: 168 	 reward: 72
# Episode 9720 	 avg length: 232 	 reward: 136
# Episode 9740 	 avg length: 245 	 reward: 157
# Episode 9760 	 avg length: 192 	 reward: 116
# Episode 9780 	 avg length: 221 	 reward: 95
# Episode 9800 	 avg length: 195 	 reward: 124
# Episode 9820 	 avg length: 207 	 reward: 120
# Episode 9840 	 avg length: 222 	 reward: 120
# Episode 9860 	 avg length: 208 	 reward: 46
# Episode 9880 	 avg length: 219 	 reward: 95
# Episode 9900 	 avg length: 227 	 reward: 125
# Episode 9920 	 avg length: 207 	 reward: 82
# Episode 9940 	 avg length: 234 	 reward: 112
# Episode 9960 	 avg length: 234 	 reward: 112
# Episode 9980 	 avg length: 218 	 reward: 76
# Episode 10000 	 avg length: 240 	 reward: 101
# Episode 10020 	 avg length: 222 	 reward: 121
# Episode 10040 	 avg length: 234 	 reward: 100
# Episode 10060 	 avg length: 249 	 reward: 104
# Episode 10080 	 avg length: 244 	 reward: 111
# Episode 10100 	 avg length: 256 	 reward: 137
# Episode 10120 	 avg length: 256 	 reward: 115
# Episode 10140 	 avg length: 242 	 reward: 135
# Episode 10160 	 avg length: 233 	 reward: 129
# Episode 10180 	 avg length: 281 	 reward: 135
# Episode 10200 	 avg length: 238 	 reward: 120
# Episode 10220 	 avg length: 263 	 reward: 128
# Episode 10240 	 avg length: 257 	 reward: 114
# Episode 10260 	 avg length: 259 	 reward: 119
# Episode 10280 	 avg length: 262 	 reward: 137
# Episode 10300 	 avg length: 243 	 reward: 98
# Episode 10320 	 avg length: 231 	 reward: 145
# Episode 10340 	 avg length: 254 	 reward: 123
# Episode 10360 	 avg length: 225 	 reward: 104
# Episode 10380 	 avg length: 262 	 reward: 160
# Episode 10400 	 avg length: 235 	 reward: 146
# Episode 10420 	 avg length: 243 	 reward: 123
# Episode 10440 	 avg length: 248 	 reward: 141
# Episode 10460 	 avg length: 223 	 reward: 111
# Episode 10480 	 avg length: 227 	 reward: 96
# Episode 10500 	 avg length: 232 	 reward: 114
# Episode 10520 	 avg length: 203 	 reward: 96
# Episode 10540 	 avg length: 184 	 reward: 94
# Episode 10560 	 avg length: 187 	 reward: 69
# Episode 10580 	 avg length: 216 	 reward: 43
# Episode 10600 	 avg length: 208 	 reward: 82
# Episode 10620 	 avg length: 262 	 reward: 99
# Episode 10640 	 avg length: 235 	 reward: 99
# Episode 10660 	 avg length: 253 	 reward: 136
# Episode 10680 	 avg length: 234 	 reward: 120
# Episode 10700 	 avg length: 223 	 reward: 107
# Episode 10720 	 avg length: 240 	 reward: 110
# Episode 10740 	 avg length: 269 	 reward: 118
# Episode 10760 	 avg length: 231 	 reward: 129
# Episode 10780 	 avg length: 210 	 reward: 68
# Episode 10800 	 avg length: 254 	 reward: 106
# Episode 10820 	 avg length: 263 	 reward: 139
# Episode 10840 	 avg length: 249 	 reward: 137
# Episode 10860 	 avg length: 231 	 reward: 117
# Episode 10880 	 avg length: 264 	 reward: 128
# Episode 10900 	 avg length: 266 	 reward: 156
# Episode 10920 	 avg length: 252 	 reward: 125
# Episode 10940 	 avg length: 264 	 reward: 140
# Episode 10960 	 avg length: 270 	 reward: 153
# Episode 10980 	 avg length: 235 	 reward: 125
# Episode 11000 	 avg length: 246 	 reward: 109
# Episode 11020 	 avg length: 254 	 reward: 133
# Episode 11040 	 avg length: 196 	 reward: 85
# Episode 11060 	 avg length: 256 	 reward: 139
# Episode 11080 	 avg length: 253 	 reward: 145
# Episode 11100 	 avg length: 277 	 reward: 143
# Episode 11120 	 avg length: 253 	 reward: 124
# Episode 11140 	 avg length: 243 	 reward: 114
# Episode 11160 	 avg length: 252 	 reward: 135
# Episode 11180 	 avg length: 258 	 reward: 118
# Episode 11200 	 avg length: 241 	 reward: 127
# Episode 11220 	 avg length: 224 	 reward: 113
# Episode 11240 	 avg length: 263 	 reward: 130
# Episode 11260 	 avg length: 212 	 reward: 94
# Episode 11280 	 avg length: 253 	 reward: 117
# Episode 11300 	 avg length: 225 	 reward: 105
# Episode 11320 	 avg length: 230 	 reward: 110
# Episode 11340 	 avg length: 204 	 reward: 109
# Episode 11360 	 avg length: 164 	 reward: 80
# Episode 11380 	 avg length: 203 	 reward: 94
# Episode 11400 	 avg length: 263 	 reward: 126
# Episode 11420 	 avg length: 245 	 reward: 133
# Episode 11440 	 avg length: 201 	 reward: 75
# Episode 11460 	 avg length: 254 	 reward: 122
# Episode 11480 	 avg length: 217 	 reward: 95
# Episode 11500 	 avg length: 266 	 reward: 149
# Episode 11520 	 avg length: 199 	 reward: 91
# Episode 11540 	 avg length: 224 	 reward: 123
# Episode 11560 	 avg length: 248 	 reward: 129
# Episode 11580 	 avg length: 231 	 reward: 112
# Episode 11600 	 avg length: 206 	 reward: 115
# Episode 11620 	 avg length: 237 	 reward: 109
# Episode 11640 	 avg length: 249 	 reward: 119
# Episode 11660 	 avg length: 200 	 reward: 68
# Episode 11680 	 avg length: 233 	 reward: 104
# Episode 11700 	 avg length: 259 	 reward: 122
# Episode 11720 	 avg length: 232 	 reward: 88
# Episode 11740 	 avg length: 256 	 reward: 126
# Episode 11760 	 avg length: 232 	 reward: 97
# Episode 11780 	 avg length: 238 	 reward: 80
# Episode 11800 	 avg length: 269 	 reward: 139
# Episode 11820 	 avg length: 269 	 reward: 106
# Episode 11840 	 avg length: 241 	 reward: 127
# Episode 11860 	 avg length: 261 	 reward: 140
# Episode 11880 	 avg length: 237 	 reward: 83
# Episode 11900 	 avg length: 266 	 reward: 122
# Episode 11920 	 avg length: 228 	 reward: 91
# Episode 11940 	 avg length: 222 	 reward: 63
# Episode 11960 	 avg length: 189 	 reward: 73
# Episode 11980 	 avg length: 207 	 reward: 63
# Episode 12000 	 avg length: 189 	 reward: 74
# Episode 12020 	 avg length: 197 	 reward: 61
# Episode 12040 	 avg length: 187 	 reward: 73
# Episode 12060 	 avg length: 154 	 reward: 36
# Episode 12080 	 avg length: 186 	 reward: 77
# Episode 12100 	 avg length: 186 	 reward: 70
# Episode 12120 	 avg length: 180 	 reward: 80
# Episode 12140 	 avg length: 131 	 reward: 22
# Episode 12160 	 avg length: 166 	 reward: 57
# Episode 12180 	 avg length: 181 	 reward: 68
# Episode 12200 	 avg length: 173 	 reward: 59
# Episode 12220 	 avg length: 206 	 reward: 87
# Episode 12240 	 avg length: 231 	 reward: 102
# Episode 12260 	 avg length: 245 	 reward: 107
# Episode 12280 	 avg length: 200 	 reward: 102
# Episode 12300 	 avg length: 208 	 reward: 101
# Episode 12320 	 avg length: 232 	 reward: 112
# Episode 12340 	 avg length: 188 	 reward: 85
# Episode 12360 	 avg length: 230 	 reward: 107
# Episode 12380 	 avg length: 227 	 reward: 102
# Episode 12400 	 avg length: 221 	 reward: 93
# Episode 12420 	 avg length: 250 	 reward: 122
# Episode 12440 	 avg length: 252 	 reward: 123
# Episode 12460 	 avg length: 241 	 reward: 121
# Episode 12480 	 avg length: 237 	 reward: 114
# Episode 12500 	 avg length: 264 	 reward: 136
# Episode 12520 	 avg length: 269 	 reward: 129
# Episode 12540 	 avg length: 271 	 reward: 125
# Episode 12560 	 avg length: 251 	 reward: 121
# Episode 12580 	 avg length: 270 	 reward: 130
# Episode 12600 	 avg length: 228 	 reward: 102
# Episode 12620 	 avg length: 235 	 reward: 122
# Episode 12640 	 avg length: 224 	 reward: 109
# Episode 12660 	 avg length: 243 	 reward: 136
# Episode 12680 	 avg length: 251 	 reward: 117
# Episode 12700 	 avg length: 265 	 reward: 142
# Episode 12720 	 avg length: 263 	 reward: 122
# Episode 12740 	 avg length: 204 	 reward: 82
# Episode 12760 	 avg length: 268 	 reward: 127
# Episode 12780 	 avg length: 218 	 reward: 77
# Episode 12800 	 avg length: 227 	 reward: 92
# Episode 12820 	 avg length: 225 	 reward: 71
# Episode 12840 	 avg length: 242 	 reward: 73
# Episode 12860 	 avg length: 205 	 reward: 83
# Episode 12880 	 avg length: 228 	 reward: 83
# Episode 12900 	 avg length: 269 	 reward: 125
# Episode 12920 	 avg length: 257 	 reward: 110
# Episode 12940 	 avg length: 229 	 reward: 94
# Episode 12960 	 avg length: 241 	 reward: 110
# Episode 12980 	 avg length: 254 	 reward: 128
# Episode 13000 	 avg length: 238 	 reward: 111
# Episode 13020 	 avg length: 243 	 reward: 103
# Episode 13040 	 avg length: 225 	 reward: 115
# Episode 13060 	 avg length: 198 	 reward: 86
# Episode 13080 	 avg length: 187 	 reward: 69
# Episode 13100 	 avg length: 212 	 reward: 87
# Episode 13120 	 avg length: 254 	 reward: 96
# Episode 13140 	 avg length: 259 	 reward: 122
# Episode 13160 	 avg length: 248 	 reward: 118
# Episode 13180 	 avg length: 265 	 reward: 112
# Episode 13200 	 avg length: 260 	 reward: 132
# Episode 13220 	 avg length: 227 	 reward: 104
# Episode 13240 	 avg length: 270 	 reward: 133
# Episode 13260 	 avg length: 263 	 reward: 130
# Episode 13280 	 avg length: 270 	 reward: 110
# Episode 13300 	 avg length: 251 	 reward: 120
# Episode 13320 	 avg length: 267 	 reward: 131
# Episode 13340 	 avg length: 254 	 reward: 122
# Episode 13360 	 avg length: 243 	 reward: 96
# Episode 13380 	 avg length: 271 	 reward: 121
# Episode 13400 	 avg length: 273 	 reward: 120
# Episode 13420 	 avg length: 277 	 reward: 136
# Episode 13440 	 avg length: 257 	 reward: 131
# Episode 13460 	 avg length: 270 	 reward: 126
# Episode 13480 	 avg length: 291 	 reward: 131
# Episode 13500 	 avg length: 249 	 reward: 89
# Episode 13520 	 avg length: 247 	 reward: 98
# Episode 13540 	 avg length: 237 	 reward: 96
# Episode 13560 	 avg length: 273 	 reward: 144
# Episode 13580 	 avg length: 249 	 reward: 112
# Episode 13600 	 avg length: 252 	 reward: 114
# Episode 13620 	 avg length: 228 	 reward: 138
# Episode 13640 	 avg length: 266 	 reward: 138
# Episode 13660 	 avg length: 240 	 reward: 118
# Episode 13680 	 avg length: 236 	 reward: 133
# Episode 13700 	 avg length: 264 	 reward: 126
# Episode 13720 	 avg length: 245 	 reward: 135
# Episode 13740 	 avg length: 212 	 reward: 111
# Episode 13760 	 avg length: 209 	 reward: 93
# Episode 13780 	 avg length: 196 	 reward: 86
# Episode 13800 	 avg length: 205 	 reward: 100
# Episode 13820 	 avg length: 233 	 reward: 103
# Episode 13840 	 avg length: 153 	 reward: 60
# Episode 13860 	 avg length: 187 	 reward: 91
# Episode 13880 	 avg length: 202 	 reward: 86
# Episode 13900 	 avg length: 142 	 reward: 60
# Episode 13920 	 avg length: 203 	 reward: 105
# Episode 13940 	 avg length: 205 	 reward: 58
# Episode 13960 	 avg length: 243 	 reward: 120
# Episode 13980 	 avg length: 247 	 reward: 111
# Episode 14000 	 avg length: 186 	 reward: 70
# Episode 14020 	 avg length: 195 	 reward: 59
# Episode 14040 	 avg length: 225 	 reward: 102
# Episode 14060 	 avg length: 217 	 reward: 78
# Episode 14080 	 avg length: 235 	 reward: 130
# Episode 14100 	 avg length: 225 	 reward: 105
# Episode 14120 	 avg length: 209 	 reward: 105
# Episode 14140 	 avg length: 216 	 reward: 95
# Episode 14160 	 avg length: 188 	 reward: 73
# Episode 14180 	 avg length: 227 	 reward: 105
# Episode 14200 	 avg length: 226 	 reward: 136
# Episode 14220 	 avg length: 219 	 reward: 156
# Episode 14240 	 avg length: 214 	 reward: 114
# Episode 14260 	 avg length: 173 	 reward: 82
# Episode 14280 	 avg length: 206 	 reward: 108
# Episode 14300 	 avg length: 185 	 reward: 102
# Episode 14320 	 avg length: 208 	 reward: 147
# Episode 14340 	 avg length: 235 	 reward: 108
# Episode 14360 	 avg length: 210 	 reward: 92
# Episode 14380 	 avg length: 149 	 reward: 63
# Episode 14400 	 avg length: 129 	 reward: 39
# Episode 14420 	 avg length: 172 	 reward: 74
# Episode 14440 	 avg length: 173 	 reward: 88
# Episode 14460 	 avg length: 172 	 reward: 69
# Episode 14480 	 avg length: 155 	 reward: 72
# Episode 14500 	 avg length: 132 	 reward: 58
# Episode 14520 	 avg length: 147 	 reward: 50
# Episode 14540 	 avg length: 173 	 reward: 88
# Episode 14560 	 avg length: 162 	 reward: 67
# Episode 14580 	 avg length: 227 	 reward: 117
# Episode 14600 	 avg length: 180 	 reward: 113
# Episode 14620 	 avg length: 206 	 reward: 89
# Episode 14640 	 avg length: 204 	 reward: 112
# Episode 14660 	 avg length: 187 	 reward: 104
# Episode 14680 	 avg length: 193 	 reward: 106
# Episode 14700 	 avg length: 196 	 reward: 104
# Episode 14720 	 avg length: 184 	 reward: 101
# Episode 14740 	 avg length: 186 	 reward: 98
# Episode 14760 	 avg length: 212 	 reward: 122
# Episode 14780 	 avg length: 198 	 reward: 100
# Episode 14800 	 avg length: 207 	 reward: 138
# Episode 14820 	 avg length: 175 	 reward: 82
# Episode 14840 	 avg length: 227 	 reward: 126
# Episode 14860 	 avg length: 205 	 reward: 86
# Episode 14880 	 avg length: 183 	 reward: 77
# Episode 14900 	 avg length: 220 	 reward: 110
# Episode 14920 	 avg length: 190 	 reward: 86
# Episode 14940 	 avg length: 185 	 reward: 91
# Episode 14960 	 avg length: 186 	 reward: 72
# Episode 14980 	 avg length: 186 	 reward: 84
# Episode 15000 	 avg length: 178 	 reward: 85
# Episode 15020 	 avg length: 175 	 reward: 78
# Episode 15040 	 avg length: 236 	 reward: 122
# Episode 15060 	 avg length: 198 	 reward: 102
# Episode 15080 	 avg length: 212 	 reward: 114
# Episode 15100 	 avg length: 204 	 reward: 96
# Episode 15120 	 avg length: 208 	 reward: 139
# Episode 15140 	 avg length: 200 	 reward: 115
# Episode 15160 	 avg length: 185 	 reward: 116
# Episode 15180 	 avg length: 216 	 reward: 94
# Episode 15200 	 avg length: 217 	 reward: 122
# Episode 15220 	 avg length: 177 	 reward: 102
# Episode 15240 	 avg length: 223 	 reward: 141
# Episode 15260 	 avg length: 205 	 reward: 100
# Episode 15280 	 avg length: 208 	 reward: 124
# Episode 15300 	 avg length: 166 	 reward: 67
# Episode 15320 	 avg length: 205 	 reward: 77
# Episode 15340 	 avg length: 206 	 reward: 132
# Episode 15360 	 avg length: 208 	 reward: 109
# Episode 15380 	 avg length: 184 	 reward: 80
# Episode 15400 	 avg length: 217 	 reward: 119
# Episode 15420 	 avg length: 218 	 reward: 93
# Episode 15440 	 avg length: 217 	 reward: 141
# Episode 15460 	 avg length: 181 	 reward: 77
# Episode 15480 	 avg length: 237 	 reward: 108
# Episode 15500 	 avg length: 178 	 reward: 86
# Episode 15520 	 avg length: 188 	 reward: 108
# Episode 15540 	 avg length: 179 	 reward: 84
# Episode 15560 	 avg length: 220 	 reward: 84
# Episode 15580 	 avg length: 210 	 reward: 112
# Episode 15600 	 avg length: 238 	 reward: 109
# Episode 15620 	 avg length: 239 	 reward: 142
# Episode 15640 	 avg length: 220 	 reward: 119
# Episode 15660 	 avg length: 191 	 reward: 109
# Episode 15680 	 avg length: 203 	 reward: 119
# Episode 15700 	 avg length: 228 	 reward: 128
# Episode 15720 	 avg length: 192 	 reward: 78
# Episode 15740 	 avg length: 251 	 reward: 129
# Episode 15760 	 avg length: 195 	 reward: 124
# Episode 15780 	 avg length: 187 	 reward: 135
# Episode 15800 	 avg length: 232 	 reward: 159
# Episode 15820 	 avg length: 211 	 reward: 86
# Episode 15840 	 avg length: 199 	 reward: 100
# Episode 15860 	 avg length: 240 	 reward: 117
# Episode 15880 	 avg length: 188 	 reward: 107
# Episode 15900 	 avg length: 206 	 reward: 104
# Episode 15920 	 avg length: 201 	 reward: 94
# Episode 15940 	 avg length: 128 	 reward: 50
# Episode 15960 	 avg length: 204 	 reward: 125
# Episode 15980 	 avg length: 172 	 reward: 38
# Episode 16000 	 avg length: 204 	 reward: 103
# Episode 16020 	 avg length: 222 	 reward: 142
# Episode 16040 	 avg length: 205 	 reward: 80
# Episode 16060 	 avg length: 210 	 reward: 103
# Episode 16080 	 avg length: 188 	 reward: 113
# Episode 16100 	 avg length: 211 	 reward: 140
# Episode 16120 	 avg length: 194 	 reward: 138
# Episode 16140 	 avg length: 195 	 reward: 102
# Episode 16160 	 avg length: 205 	 reward: 114
# Episode 16180 	 avg length: 183 	 reward: 84
# Episode 16200 	 avg length: 187 	 reward: 106
# Episode 16220 	 avg length: 230 	 reward: 115
# Episode 16240 	 avg length: 178 	 reward: 101
# Episode 16260 	 avg length: 193 	 reward: 87
# Episode 16280 	 avg length: 226 	 reward: 112
# Episode 16300 	 avg length: 230 	 reward: 126
# Episode 16320 	 avg length: 225 	 reward: 133
# Episode 16340 	 avg length: 213 	 reward: 94
# Episode 16360 	 avg length: 219 	 reward: 118
# Episode 16380 	 avg length: 191 	 reward: 83
# Episode 16400 	 avg length: 193 	 reward: 100
# Episode 16420 	 avg length: 198 	 reward: 96
# Episode 16440 	 avg length: 248 	 reward: 111
# Episode 16460 	 avg length: 243 	 reward: 121
# Episode 16480 	 avg length: 203 	 reward: 99
# Episode 16500 	 avg length: 201 	 reward: 102
# Episode 16520 	 avg length: 199 	 reward: 102
# Episode 16540 	 avg length: 213 	 reward: 112
# Episode 16560 	 avg length: 238 	 reward: 120
# Episode 16580 	 avg length: 202 	 reward: 85
# Episode 16600 	 avg length: 179 	 reward: 79
# Episode 16620 	 avg length: 218 	 reward: 97
# Episode 16640 	 avg length: 215 	 reward: 86
# Episode 16660 	 avg length: 185 	 reward: 105
# Episode 16680 	 avg length: 179 	 reward: 67
# Episode 16700 	 avg length: 179 	 reward: 50
# Episode 16720 	 avg length: 200 	 reward: 57
# Episode 16740 	 avg length: 193 	 reward: 89
# Episode 16760 	 avg length: 204 	 reward: 67
# Episode 16780 	 avg length: 205 	 reward: 101
# Episode 16800 	 avg length: 197 	 reward: 74
# Episode 16820 	 avg length: 210 	 reward: 79
# Episode 16840 	 avg length: 167 	 reward: 61
# Episode 16860 	 avg length: 182 	 reward: 93
# Episode 16880 	 avg length: 196 	 reward: 65
# Episode 16900 	 avg length: 196 	 reward: 80
# Episode 16920 	 avg length: 222 	 reward: 80
# Episode 16940 	 avg length: 169 	 reward: 58
# Episode 16960 	 avg length: 192 	 reward: 80
# Episode 16980 	 avg length: 199 	 reward: 72
# Episode 17000 	 avg length: 170 	 reward: 73
# Episode 17020 	 avg length: 191 	 reward: 85
# Episode 17040 	 avg length: 223 	 reward: 97
# Episode 17060 	 avg length: 238 	 reward: 94
# Episode 17080 	 avg length: 193 	 reward: 64
# Episode 17100 	 avg length: 226 	 reward: 95
# Episode 17120 	 avg length: 176 	 reward: 91
# Episode 17140 	 avg length: 209 	 reward: 108
# Episode 17160 	 avg length: 243 	 reward: 117
# Episode 17180 	 avg length: 188 	 reward: 115
# Episode 17200 	 avg length: 229 	 reward: 105
# Episode 17220 	 avg length: 179 	 reward: 88
# Episode 17240 	 avg length: 232 	 reward: 117
# Episode 17260 	 avg length: 186 	 reward: 71
# Episode 17280 	 avg length: 238 	 reward: 113
# Episode 17300 	 avg length: 232 	 reward: 126
# Episode 17320 	 avg length: 191 	 reward: 84
# Episode 17340 	 avg length: 196 	 reward: 86
# Episode 17360 	 avg length: 205 	 reward: 67
# Episode 17380 	 avg length: 219 	 reward: 115
# Episode 17400 	 avg length: 193 	 reward: 104
# Episode 17420 	 avg length: 238 	 reward: 120
# Episode 17440 	 avg length: 222 	 reward: 107
# Episode 17460 	 avg length: 226 	 reward: 94
# Episode 17480 	 avg length: 228 	 reward: 123
# Episode 17500 	 avg length: 223 	 reward: 136
# Episode 17520 	 avg length: 218 	 reward: 129
# Episode 17540 	 avg length: 208 	 reward: 93
# Episode 17560 	 avg length: 258 	 reward: 122
# Episode 17580 	 avg length: 245 	 reward: 127
# Episode 17600 	 avg length: 244 	 reward: 143
# Episode 17620 	 avg length: 243 	 reward: 132
# Episode 17640 	 avg length: 223 	 reward: 128
# Episode 17660 	 avg length: 229 	 reward: 144
# Episode 17680 	 avg length: 248 	 reward: 165
# Episode 17700 	 avg length: 238 	 reward: 145
# Episode 17720 	 avg length: 229 	 reward: 183
# Episode 17740 	 avg length: 234 	 reward: 124
# Episode 17760 	 avg length: 212 	 reward: 99
# Episode 17780 	 avg length: 213 	 reward: 94
# Episode 17800 	 avg length: 266 	 reward: 144
# Episode 17820 	 avg length: 240 	 reward: 124
# Episode 17840 	 avg length: 248 	 reward: 156
# Episode 17860 	 avg length: 248 	 reward: 126
# Episode 17880 	 avg length: 234 	 reward: 114
# Episode 17900 	 avg length: 208 	 reward: 100
# Episode 17920 	 avg length: 196 	 reward: 97
# Episode 17940 	 avg length: 221 	 reward: 129
# Episode 17960 	 avg length: 208 	 reward: 119
# Episode 17980 	 avg length: 209 	 reward: 86
# Episode 18000 	 avg length: 215 	 reward: 103
# Episode 18020 	 avg length: 208 	 reward: 87
# Episode 18040 	 avg length: 246 	 reward: 142
# Episode 18060 	 avg length: 206 	 reward: 100
# Episode 18080 	 avg length: 182 	 reward: 64
# Episode 18100 	 avg length: 220 	 reward: 101
# Episode 18120 	 avg length: 238 	 reward: 125
# Episode 18140 	 avg length: 206 	 reward: 76
# Episode 18160 	 avg length: 225 	 reward: 120
# Episode 18180 	 avg length: 212 	 reward: 87
# Episode 18200 	 avg length: 199 	 reward: 95
# Episode 18220 	 avg length: 155 	 reward: 42
# Episode 18240 	 avg length: 184 	 reward: 78
# Episode 18260 	 avg length: 192 	 reward: 71
# Episode 18280 	 avg length: 207 	 reward: 86
# Episode 18300 	 avg length: 192 	 reward: 93
# Episode 18320 	 avg length: 184 	 reward: 85
# Episode 18340 	 avg length: 235 	 reward: 122
# Episode 18360 	 avg length: 229 	 reward: 117
# Episode 18380 	 avg length: 222 	 reward: 122
# Episode 18400 	 avg length: 230 	 reward: 113
# Episode 18420 	 avg length: 186 	 reward: 72
# Episode 18440 	 avg length: 221 	 reward: 121
# Episode 18460 	 avg length: 191 	 reward: 96
# Episode 18480 	 avg length: 201 	 reward: 86
# Episode 18500 	 avg length: 245 	 reward: 130
# Episode 18520 	 avg length: 213 	 reward: 113
# Episode 18540 	 avg length: 235 	 reward: 135
# Episode 18560 	 avg length: 246 	 reward: 119
# Episode 18580 	 avg length: 241 	 reward: 120
# Episode 18600 	 avg length: 234 	 reward: 140
# Episode 18620 	 avg length: 249 	 reward: 127
# Episode 18640 	 avg length: 247 	 reward: 116
# Episode 18660 	 avg length: 245 	 reward: 109
# Episode 18680 	 avg length: 215 	 reward: 113
# Episode 18700 	 avg length: 264 	 reward: 117
# Episode 18720 	 avg length: 242 	 reward: 136
# Episode 18740 	 avg length: 221 	 reward: 151
# Episode 18760 	 avg length: 225 	 reward: 124
# Episode 18780 	 avg length: 225 	 reward: 120
# Episode 18800 	 avg length: 237 	 reward: 120
# Episode 18820 	 avg length: 225 	 reward: 155
# Episode 18840 	 avg length: 241 	 reward: 127
# Episode 18860 	 avg length: 250 	 reward: 124
# Episode 18880 	 avg length: 233 	 reward: 114
# Episode 18900 	 avg length: 261 	 reward: 158
# Episode 18920 	 avg length: 238 	 reward: 148
# Episode 18940 	 avg length: 213 	 reward: 81
# Episode 18960 	 avg length: 240 	 reward: 115
# Episode 18980 	 avg length: 251 	 reward: 111
# Episode 19000 	 avg length: 216 	 reward: 109
# Episode 19020 	 avg length: 279 	 reward: 120
# Episode 19040 	 avg length: 255 	 reward: 164
# Episode 19060 	 avg length: 254 	 reward: 120
# Episode 19080 	 avg length: 241 	 reward: 138
# Episode 19100 	 avg length: 240 	 reward: 126
# Episode 19120 	 avg length: 233 	 reward: 107
# Episode 19140 	 avg length: 233 	 reward: 106
# Episode 19160 	 avg length: 219 	 reward: 112
# Episode 19180 	 avg length: 177 	 reward: 106
# Episode 19200 	 avg length: 198 	 reward: 130
# Episode 19220 	 avg length: 194 	 reward: 103
# Episode 19240 	 avg length: 252 	 reward: 122
# Episode 19260 	 avg length: 252 	 reward: 138
# Episode 19280 	 avg length: 212 	 reward: 140
# Episode 19300 	 avg length: 214 	 reward: 104
# Episode 19320 	 avg length: 260 	 reward: 156
# Episode 19340 	 avg length: 230 	 reward: 132
# Episode 19360 	 avg length: 188 	 reward: 90
# Episode 19380 	 avg length: 184 	 reward: 78
# Episode 19400 	 avg length: 202 	 reward: 104
# Episode 19420 	 avg length: 234 	 reward: 135
# Episode 19440 	 avg length: 243 	 reward: 158
# Episode 19460 	 avg length: 205 	 reward: 109
# Episode 19480 	 avg length: 237 	 reward: 141
# Episode 19500 	 avg length: 231 	 reward: 132
# Episode 19520 	 avg length: 222 	 reward: 121
# Episode 19540 	 avg length: 234 	 reward: 119
# Episode 19560 	 avg length: 223 	 reward: 102
# Episode 19580 	 avg length: 262 	 reward: 166
# Episode 19600 	 avg length: 257 	 reward: 180
# Episode 19620 	 avg length: 250 	 reward: 144
# Episode 19640 	 avg length: 212 	 reward: 153
# Episode 19660 	 avg length: 255 	 reward: 158
# Episode 19680 	 avg length: 238 	 reward: 137
# Episode 19700 	 avg length: 240 	 reward: 148
# Episode 19720 	 avg length: 264 	 reward: 154
# Episode 19740 	 avg length: 226 	 reward: 121
# Episode 19760 	 avg length: 219 	 reward: 109
# Episode 19780 	 avg length: 193 	 reward: 122
# Episode 19800 	 avg length: 244 	 reward: 131
# Episode 19820 	 avg length: 265 	 reward: 134
# Episode 19840 	 avg length: 271 	 reward: 140
# Episode 19860 	 avg length: 234 	 reward: 134
# Episode 19880 	 avg length: 227 	 reward: 114
# Episode 19900 	 avg length: 221 	 reward: 113
# Episode 19920 	 avg length: 263 	 reward: 149
# Episode 19940 	 avg length: 244 	 reward: 122
# Episode 19960 	 avg length: 215 	 reward: 112
# Episode 19980 	 avg length: 239 	 reward: 110
# Episode 20000 	 avg length: 279 	 reward: 134
# Episode 20020 	 avg length: 226 	 reward: 137
# Episode 20040 	 avg length: 257 	 reward: 140
# Episode 20060 	 avg length: 234 	 reward: 130
# Episode 20080 	 avg length: 259 	 reward: 122
# Episode 20100 	 avg length: 260 	 reward: 137
# Episode 20120 	 avg length: 230 	 reward: 115
# Episode 20140 	 avg length: 258 	 reward: 144
# Episode 20160 	 avg length: 238 	 reward: 112
# Episode 20180 	 avg length: 260 	 reward: 144
# Episode 20200 	 avg length: 217 	 reward: 117
# Episode 20220 	 avg length: 215 	 reward: 94
# Episode 20240 	 avg length: 263 	 reward: 146
# Episode 20260 	 avg length: 269 	 reward: 133
# Episode 20280 	 avg length: 275 	 reward: 146
# Episode 20300 	 avg length: 264 	 reward: 152
# Episode 20320 	 avg length: 256 	 reward: 155
# Episode 20340 	 avg length: 279 	 reward: 132
# Episode 20360 	 avg length: 264 	 reward: 163
# Episode 20380 	 avg length: 255 	 reward: 144
# Episode 20400 	 avg length: 271 	 reward: 157
# Episode 20420 	 avg length: 257 	 reward: 158
# Episode 20440 	 avg length: 261 	 reward: 153
# Episode 20460 	 avg length: 246 	 reward: 108
# Episode 20480 	 avg length: 282 	 reward: 148
# Episode 20500 	 avg length: 289 	 reward: 164
# Episode 20520 	 avg length: 265 	 reward: 123
# Episode 20540 	 avg length: 279 	 reward: 154
# Episode 20560 	 avg length: 281 	 reward: 146
# Episode 20580 	 avg length: 231 	 reward: 141
# Episode 20600 	 avg length: 281 	 reward: 164
# Episode 20620 	 avg length: 247 	 reward: 134
# Episode 20640 	 avg length: 262 	 reward: 135
# Episode 20660 	 avg length: 263 	 reward: 156
# Episode 20680 	 avg length: 243 	 reward: 143
# Episode 20700 	 avg length: 235 	 reward: 97
# Episode 20720 	 avg length: 228 	 reward: 113
# Episode 20740 	 avg length: 266 	 reward: 132
# Episode 20760 	 avg length: 269 	 reward: 156
# Episode 20780 	 avg length: 263 	 reward: 123
# Episode 20800 	 avg length: 238 	 reward: 124
# Episode 20820 	 avg length: 264 	 reward: 138
# Episode 20840 	 avg length: 253 	 reward: 137
# Episode 20860 	 avg length: 257 	 reward: 161
# Episode 20880 	 avg length: 250 	 reward: 133
# Episode 20900 	 avg length: 234 	 reward: 139
# Episode 20920 	 avg length: 246 	 reward: 140
# Episode 20940 	 avg length: 230 	 reward: 142
# Episode 20960 	 avg length: 242 	 reward: 143
# Episode 20980 	 avg length: 255 	 reward: 138
# Episode 21000 	 avg length: 226 	 reward: 135
# Episode 21020 	 avg length: 231 	 reward: 108
# Episode 21040 	 avg length: 224 	 reward: 151
# Episode 21060 	 avg length: 214 	 reward: 122
# Episode 21080 	 avg length: 211 	 reward: 119
# Episode 21100 	 avg length: 206 	 reward: 90
# Episode 21120 	 avg length: 239 	 reward: 119
# Episode 21140 	 avg length: 228 	 reward: 103
# Episode 21160 	 avg length: 214 	 reward: 103
# Episode 21180 	 avg length: 206 	 reward: 106
# Episode 21200 	 avg length: 221 	 reward: 102
# Episode 21220 	 avg length: 196 	 reward: 82
# Episode 21240 	 avg length: 268 	 reward: 143
# Episode 21260 	 avg length: 274 	 reward: 159
# Episode 21280 	 avg length: 235 	 reward: 117
# Episode 21300 	 avg length: 265 	 reward: 118
# Episode 21320 	 avg length: 230 	 reward: 106
# Episode 21340 	 avg length: 265 	 reward: 132
# Episode 21360 	 avg length: 253 	 reward: 146
# Episode 21380 	 avg length: 235 	 reward: 106
# Episode 21400 	 avg length: 210 	 reward: 93
# Episode 21420 	 avg length: 220 	 reward: 129
# Episode 21440 	 avg length: 259 	 reward: 134
# Episode 21460 	 avg length: 282 	 reward: 155
# Episode 21480 	 avg length: 226 	 reward: 115
# Episode 21500 	 avg length: 249 	 reward: 131
# Episode 21520 	 avg length: 224 	 reward: 125
# Episode 21540 	 avg length: 205 	 reward: 113
# Episode 21560 	 avg length: 248 	 reward: 134
# Episode 21580 	 avg length: 203 	 reward: 97
# Episode 21600 	 avg length: 183 	 reward: 72
# Episode 21620 	 avg length: 224 	 reward: 100
# Episode 21640 	 avg length: 239 	 reward: 102
# Episode 21660 	 avg length: 231 	 reward: 118
# Episode 21680 	 avg length: 203 	 reward: 91
# Episode 21700 	 avg length: 232 	 reward: 123
# Episode 21720 	 avg length: 251 	 reward: 141
# Episode 21740 	 avg length: 231 	 reward: 157
# Episode 21760 	 avg length: 204 	 reward: 108
# Episode 21780 	 avg length: 234 	 reward: 113
# Episode 21800 	 avg length: 218 	 reward: 110
# Episode 21820 	 avg length: 238 	 reward: 106
# Episode 21840 	 avg length: 192 	 reward: 92
# Episode 21860 	 avg length: 212 	 reward: 103
# Episode 21880 	 avg length: 192 	 reward: 86
# Episode 21900 	 avg length: 228 	 reward: 118
# Episode 21920 	 avg length: 224 	 reward: 121
# Episode 21940 	 avg length: 203 	 reward: 68
# Episode 21960 	 avg length: 248 	 reward: 110
# Episode 21980 	 avg length: 265 	 reward: 124
# Episode 22000 	 avg length: 286 	 reward: 136
# Episode 22020 	 avg length: 248 	 reward: 146
# Episode 22040 	 avg length: 271 	 reward: 128
# Episode 22060 	 avg length: 263 	 reward: 141
# Episode 22080 	 avg length: 273 	 reward: 143
# Episode 22100 	 avg length: 245 	 reward: 114
# Episode 22120 	 avg length: 269 	 reward: 132
# Episode 22140 	 avg length: 252 	 reward: 117
# Episode 22160 	 avg length: 262 	 reward: 122
# Episode 22180 	 avg length: 291 	 reward: 149
# Episode 22200 	 avg length: 263 	 reward: 131
# Episode 22220 	 avg length: 267 	 reward: 141
# Episode 22240 	 avg length: 257 	 reward: 125
# Episode 22260 	 avg length: 225 	 reward: 108
# Episode 22280 	 avg length: 279 	 reward: 154
# Episode 22300 	 avg length: 249 	 reward: 124
# Episode 22320 	 avg length: 261 	 reward: 137
# Episode 22340 	 avg length: 228 	 reward: 131
# Episode 22360 	 avg length: 227 	 reward: 124
# Episode 22380 	 avg length: 262 	 reward: 132
# Episode 22400 	 avg length: 282 	 reward: 158
# Episode 22420 	 avg length: 238 	 reward: 125
# Episode 22440 	 avg length: 261 	 reward: 159
# Episode 22460 	 avg length: 258 	 reward: 143
# Episode 22480 	 avg length: 290 	 reward: 147
# Episode 22500 	 avg length: 265 	 reward: 129
# Episode 22520 	 avg length: 269 	 reward: 145
# Episode 22540 	 avg length: 260 	 reward: 136
# Episode 22560 	 avg length: 287 	 reward: 161
# Episode 22580 	 avg length: 282 	 reward: 150
# Episode 22600 	 avg length: 278 	 reward: 137
# Episode 22620 	 avg length: 289 	 reward: 149
# Episode 22640 	 avg length: 299 	 reward: 159
# Episode 22660 	 avg length: 290 	 reward: 165
# Episode 22680 	 avg length: 265 	 reward: 132
# Episode 22700 	 avg length: 262 	 reward: 128
# Episode 22720 	 avg length: 264 	 reward: 128
# Episode 22740 	 avg length: 245 	 reward: 90
# Episode 22760 	 avg length: 292 	 reward: 142
# Episode 22780 	 avg length: 243 	 reward: 110
# Episode 22800 	 avg length: 283 	 reward: 152
# Episode 22820 	 avg length: 283 	 reward: 148
# Episode 22840 	 avg length: 263 	 reward: 129
# Episode 22860 	 avg length: 279 	 reward: 140
# Episode 22880 	 avg length: 262 	 reward: 136
# Episode 22900 	 avg length: 247 	 reward: 130
# Episode 22920 	 avg length: 239 	 reward: 119
# Episode 22940 	 avg length: 264 	 reward: 132
# Episode 22960 	 avg length: 264 	 reward: 137
# Episode 22980 	 avg length: 236 	 reward: 121
# Episode 23000 	 avg length: 245 	 reward: 137
# Episode 23020 	 avg length: 268 	 reward: 152
# Episode 23040 	 avg length: 272 	 reward: 152
# Episode 23060 	 avg length: 248 	 reward: 119
# Episode 23080 	 avg length: 275 	 reward: 154
# Episode 23100 	 avg length: 228 	 reward: 117
# Episode 23120 	 avg length: 234 	 reward: 98
# Episode 23140 	 avg length: 215 	 reward: 98
# Episode 23160 	 avg length: 216 	 reward: 95
# Episode 23180 	 avg length: 236 	 reward: 127
# Episode 23200 	 avg length: 196 	 reward: 146
# Episode 23220 	 avg length: 200 	 reward: 153
# Episode 23240 	 avg length: 173 	 reward: 136
# Episode 23260 	 avg length: 205 	 reward: 202
# Episode 23280 	 avg length: 195 	 reward: 173
# Episode 23300 	 avg length: 167 	 reward: 148
# Episode 23320 	 avg length: 192 	 reward: 157
# Episode 23340 	 avg length: 170 	 reward: 79
# Episode 23360 	 avg length: 204 	 reward: 119
# Episode 23380 	 avg length: 188 	 reward: 78
# Episode 23400 	 avg length: 190 	 reward: 98
# Episode 23420 	 avg length: 190 	 reward: 89
# #### Solved! ######
